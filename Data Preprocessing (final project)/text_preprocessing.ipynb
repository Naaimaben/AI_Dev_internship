# %% [markdown]
# # **FINAL PROJECT for the AI Developer Internship at Technocolabs Softwares**
#
# ## Task 1: Data Preprocessing by Naaima BEN KADOUR

# %% [markdown]
# # Preprocessing of the dataset question_bank.csv

# %% [markdown]
# ### Import all the modules

# %%
import numpy as np
import pandas as pd
import re
import nltk
import spacy
import string
from nltk.corpus import stopwords
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import wordnet

# %% [markdown]
# ### Read the dataset using pandas

# %%
pd.options.mode.chained_assignment = None

full_df = pd.read_csv("question_bank.csv", nrows=836)
df = full_df[["ClarifyingQuestion"]]
df["Text"] = df["ClarifyingQuestion"].astype(str)
full_df.head(10)
# Out:
#     qrel                                 ClarifyingQuestion
# 0  q_149                                Which color blocks?
# 1  q_436  After you remove the one green block there are...
# 2  q_111              in any square west of the red blocks?
# 3  q_653             Should I destory east or west puyrple?
# 4  q_170        Where exactly am I placing the blue blocks?
# 5  q_479      What purple blocks? There are none only blue.
# 6  q_321  How do i place in the bottom if the purple are...
# 7  q_236      Where on the map do I place the yellow block?
# 8  q_293  Should the two purple blocks I'm setting be pl...
# 9  q_965  How many blue blocks am I adding to the first ...

# %% [markdown]
# ### Start the preprocessing by applying the lowercase to all the data from ClarifyingQuestion column

# %%
df["lowercase"] = df["ClarifyingQuestion"].str.lower()
df.head()
# Out:
#                                   ClarifyingQuestion  \
# 0                                Which color blocks?
# 1  After you remove the one green block there are...
# 2              in any square west of the red blocks?
# 3             Should I destory east or west puyrple?
# 4        Where exactly am I placing the blue blocks?
#
#                                                 Text  \
# 0                                Which color blocks?
# 1  After you remove the one green block there are...
# 2              in any square west of the red blocks?
# 3             Should I destory east or west puyrple?
# 4        Where exactly am I placing the blue blocks?
#
#                                            lowercase
# 0                                which color blocks?
# 1  after you remove the one green block there are...
# 2              in any square west of the red blocks?
# 3             should i destory east or west puyrple?
# 4        where exactly am i placing the blue blocks?

# %% [markdown]
# ### Eliminate the punctuation from the data

# %%
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(text):
    """custom function to remove the punctuation"""
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

df["pnctRemoved"] = df["lowercase"].apply(lambda text: remove_punctuation(text))
df.head()
# Out:
#                                   ClarifyingQuestion  \
# 0                                Which color blocks?
# 1  After you remove the one green block there are...
# 2              in any square west of the red blocks?
# 3             Should I destory east or west puyrple?
# 4        Where exactly am I placing the blue blocks?
#
#                                                 Text  \
# 0                                Which color blocks?
# 1  After you remove the one green block there are...
# 2              in any square west of the red blocks?
# 3             Should I destory east or west puyrple?
# 4        Where exactly am I placing the blue blocks?
#
#                                            lowercase  \
# 0                                which color blocks?
# 1  after you remove the one green block there are...
# 2              in any square west of the red blocks?
# 3             should i destory east or west puyrple?
# 4        where exactly am i placing the blue blocks?
#
#                                          pnctRemoved
# 0                                 which color blocks
# 1  after you remove the one green block there are...
# 2               in any square west of the red blocks
# 3              should i destory east or west puyrple
# 4         where exactly am i placing the blue blocks

# %% [markdown]
# ### Delete the stopwords from the data

# %%
#download the stopwords
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """custom function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

df["text_wo_stop"] = df["pnctRemoved"].apply(lambda text: remove_stopwords(text))
df.head()
# Out:
#                                   ClarifyingQuestion  \
# 0                                Which color blocks?
# 1  After you remove the one green block there are...
# 2              in any square west of the red blocks?
# 3             Should I destory east or west puyrple?
# 4        Where exactly am I placing the blue blocks?
#
#                                                 Text  \
# 0                                Which color blocks?
# 1  After you remove the one green block there are...
# 2              in any square west of the red blocks?
# 3             Should I destory east or west puyrple?
# 4        Where exactly am I placing the blue blocks?
#
#                                            lowercase  \
# 0                                which color blocks?
# 1  after you remove the one green block there are...
# 2              in any square west of the red blocks?
# 3             should i destory east or west puyrple?
# 4        where exactly am i placing the blue blocks?
#
#                                          pnctRemoved  \
# 0                                 which color blocks
# 1  after you remove the one green block there are...
# 2               in any square west of the red blocks
# 3              should i destory east or west puyrple
# 4         where exactly am i placing the blue blocks
#
#                                         text_wo_stop
# 0                                       color blocks
# 1  remove one green block green blocks green bloc...
# 2                             square west red blocks
# 3                          destory east west puyrple
# 4                        exactly placing blue blocks

# %% [markdown]
# ### Lemmatization (reducing inflected words)

# %%
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
#Lemmatization

lemmatizer = WordNetLemmatizer()
wordnet_map = {"N":wordnet.NOUN, "V":wordnet.VERB, "J":wordnet.ADJ, "R":wordnet.ADV}
def lemmatize_words(text):
    pos_tagged_text = nltk.pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_tagged_text])

df["text_lemmatized"] = df["text_wo_stop"].apply(lambda text: lemmatize_words(text))
df.head()
# Out:
#                                   ClarifyingQuestion  \
# 0                                Which color blocks?
# 1  After you remove the one green block there are...
# 2              in any square west of the red blocks?
# 3             Should I destory east or west puyrple?
# 4        Where exactly am I placing the blue blocks?
#
#                                                 Text  \
# 0                                Which color blocks?
# 1  After you remove the one green block there are...
# 2              in any square west of the red blocks?
# 3             Should I destory east or west puyrple?
# 4        Where exactly am I placing the blue blocks?
#
#                                            lowercase  \
# 0                                which color blocks?
# 1  after you remove the one green block there are...
# 2              in any square west of the red blocks?
# 3             should i destory east or west puyrple?
# 4        where exactly am i placing the blue blocks?
#
#                                          pnctRemoved  \
# 0                                 which color blocks
# 1  after you remove the one green block there are...
# 2               in any square west of the red blocks
# 3              should i destory east or west puyrple
# 4         where exactly am i placing the blue blocks
#
#                                         text_wo_stop  \
# 0                                       color blocks
# 1  remove one green block green blocks green bloc...
# 2                             square west red blocks
# 3                          destory east west puyrple
# 4                        exactly placing blue blocks
#
#                                         text_stemmed  \
# 0                                        color block
# 1  remov one green block green block green block ...
# 2                               squar west red block
# 3                           destori east west puyrpl
# 4                           exactli place blue block
#
#                                      text_lemmatized
# 0                                        color block
# 1  remove one green block green block green block...
# 2                              square west red block
# 3                          destory east west puyrple
# 4                           exactly place blue block

# %%
df.drop(["text_stemmed"], axis=1, inplace=True)

# %%
#show the dataframe
df
# Out:
#                                     ClarifyingQuestion  \
# 0                                  Which color blocks?
# 1    After you remove the one green block there are...
# 2                in any square west of the red blocks?
# 3               Should I destory east or west puyrple?
# 4          Where exactly am I placing the blue blocks?
# ..                                                 ...
# 830  Where should I build the blue blocks after des...
# 831  Would the row of 2 blocks be under the blue st...
# 832           There are only orange blocks not yellow.
# 833          Left and right as I face which direction?
# 834      Which way should the orange blocks be placed?
#
#                                                   Text  \
# 0                                  Which color blocks?
# 1    After you remove the one green block there are...
# 2                in any square west of the red blocks?
# 3               Should I destory east or west puyrple?
# 4          Where exactly am I placing the blue blocks?
# ..                                                 ...
# 830  Where should I build the blue blocks after des...
# 831  Would the row of 2 blocks be under the blue st...
# 832           There are only orange blocks not yellow.
# 833          Left and right as I face which direction?
# 834      Which way should the orange blocks be placed?
#
#                                              lowercase  \
# 0                                  which color blocks?
# 1    after you remove the one green block there are...
# 2                in any square west of the red blocks?
# 3               should i destory east or west puyrple?
# 4          where exactly am i placing the blue blocks?
# ..                                                 ...
# 830  where should i build the blue blocks after des...
# 831  would the row of 2 blocks be under the blue st...
# 832           there are only orange blocks not yellow.
# 833          left and right as i face which direction?
# 834      which way should the orange blocks be placed?
#
#                                            pnctRemoved  \
# 0                                   which color blocks
# 1    after you remove the one green block there are...
# 2                 in any square west of the red blocks
# 3                should i destory east or west puyrple
# 4           where exactly am i placing the blue blocks
# ..                                                 ...
# 830  where should i build the blue blocks after des...
# 831  would the row of 2 blocks be under the blue st...
# 832            there are only orange blocks not yellow
# 833           left and right as i face which direction
# 834       which way should the orange blocks be placed
#
#                                           text_wo_stop  \
# 0                                         color blocks
# 1    remove one green block green blocks green bloc...
# 2                               square west red blocks
# 3                            destory east west puyrple
# 4                          exactly placing blue blocks
# ..                                                 ...
# 830  build blue blocks destroying red blocks replac...
# 831            would row 2 blocks blue structure added
# 832                               orange blocks yellow
# 833                          left right face direction
# 834                           way orange blocks placed
#
#                                        text_lemmatized
# 0                                          color block
# 1    remove one green block green block green block...
# 2                                square west red block
# 3                            destory east west puyrple
# 4                             exactly place blue block
# ..                                                 ...
# 830  build blue block destroy red block replace red...
# 831               would row 2 block blue structure add
# 832                                orange block yellow
# 833                          left right face direction
# 834                             way orange block place
#
# [835 rows x 6 columns]

# %% [markdown]
# ### Save the dataframe to csv file

# %%
df.to_csv(r'cleaned_questionsBank.csv', index=False)

# %% [markdown]
# # Preprocessing of the dataset clarifying_questions_train.csv

# %% [markdown]
# ### Read the dataset using pandas

# %%
pd.options.mode.chained_assignment = None

C_questions = pd.read_csv("clarifying_questions_train.csv", nrows=6827)
C_questions
# Out:
#             GameId                             ClarifyingQuestion  \
# 0        CQ-game-1                                            NaN
# 1       CQ-game-10                                            NaN
# 2       CQ-game-10                                            NaN
# 3     CQ-game-1000                            Which color blocks?
# 4     CQ-game-1001                                            NaN
# ...            ...                                            ...
# 6822   CQ-game-992                                            NaN
# 6823   CQ-game-993                                            NaN
# 6824   CQ-game-994                                            NaN
# 6825   CQ-game-995  Which way should the orange blocks be placed?
# 6826   CQ-game-996                                            NaN
#
#                                    InitializedWorldPath  \
# 0     initial_world_states/builder-data/34-c135/step-20
# 1     initial_world_states/builder-data/12-c139/step-22
# 2     initial_world_states/builder-data/12-c139/step-22
# 3      initial_world_states/builder-data/23-c135/step-2
# 4       initial_world_states/builder-data/4-c96/step-18
# ...                                                 ...
# 6822   initial_world_states/builder-data/32-c126/step-2
# 6823   initial_world_states/builder-data/2-c116/step-16
# 6824     initial_world_states/builder-data/7-c73/step-4
# 6825    initial_world_states/builder-data/11-c97/step-4
# 6826   initial_world_states/builder-data/2-c116/step-14
#
#                                        InputInstruction IsInstructionClear  \
# 0     Destroy the two blocks over the row that is co...                Yes
# 1     Place one yellow block on top of each purple b...                Yes
# 2     Place one yellow block on top of each purple b...                Yes
# 3     Place four blocks to the east of the highest b...                 No
# 4     Locate the purple structure and the block on i...                Yes
# ...                                                 ...                ...
# 6822  Place a yellow block immediately to the west o...                Yes
# 6823  Stack three green blocks on top of every green...                Yes
# 6824  Place a green block on top of the highest gree...                Yes
# 6825  Facing North place a column of three green blo...                 No
# 6826  - Facing north place yellow cube to the right ...                Yes
#
#      Partition   qrel                                              qbank
# 0        train    NaN                                                NaN
# 1        train    NaN                                                NaN
# 2        train    NaN                                                NaN
# 3        train  q_149  'q_696', 'q_203', 'q_516', 'q_677', 'q_769', '...
# 4        train    NaN                                                NaN
# ...        ...    ...                                                ...
# 6822     train    NaN                                                NaN
# 6823     train    NaN                                                NaN
# 6824     train    NaN                                                NaN
# 6825     train  q_241  'q_683', 'q_918', 'q_144', 'q_710', 'q_273', '...
# 6826     train    NaN                                                NaN
#
# [6827 rows x 8 columns]

# %%
C_questions["InputInstruction"].astype(str)
C_questions.head()
# Out:
#          GameId   ClarifyingQuestion  \
# 0     CQ-game-1                  NaN
# 1    CQ-game-10                  NaN
# 2    CQ-game-10                  NaN
# 3  CQ-game-1000  Which color blocks?
# 4  CQ-game-1001                  NaN
#
#                                 InitializedWorldPath  \
# 0  initial_world_states/builder-data/34-c135/step-20
# 1  initial_world_states/builder-data/12-c139/step-22
# 2  initial_world_states/builder-data/12-c139/step-22
# 3   initial_world_states/builder-data/23-c135/step-2
# 4    initial_world_states/builder-data/4-c96/step-18
#
#                                     InputInstruction IsInstructionClear  \
# 0  Destroy the two blocks over the row that is co...                Yes
# 1  Place one yellow block on top of each purple b...                Yes
# 2  Place one yellow block on top of each purple b...                Yes
# 3  Place four blocks to the east of the highest b...                 No
# 4  Locate the purple structure and the block on i...                Yes
#
#   Partition   qrel                                              qbank
# 0     train    NaN                                                NaN
# 1     train    NaN                                                NaN
# 2     train    NaN                                                NaN
# 3     train  q_149  'q_696', 'q_203', 'q_516', 'q_677', 'q_769', '...
# 4     train    NaN                                                NaN

# %% [markdown]
# ### Lowercase

# %%
C_questions["II_lowercase"] = C_questions["InputInstruction"].str.lower()
C_questions.head()
# Out:
#          GameId   ClarifyingQuestion  \
# 0     CQ-game-1                  NaN
# 1    CQ-game-10                  NaN
# 2    CQ-game-10                  NaN
# 3  CQ-game-1000  Which color blocks?
# 4  CQ-game-1001                  NaN
#
#                                 InitializedWorldPath  \
# 0  initial_world_states/builder-data/34-c135/step-20
# 1  initial_world_states/builder-data/12-c139/step-22
# 2  initial_world_states/builder-data/12-c139/step-22
# 3   initial_world_states/builder-data/23-c135/step-2
# 4    initial_world_states/builder-data/4-c96/step-18
#
#                                     InputInstruction IsInstructionClear  \
# 0  Destroy the two blocks over the row that is co...                Yes
# 1  Place one yellow block on top of each purple b...                Yes
# 2  Place one yellow block on top of each purple b...                Yes
# 3  Place four blocks to the east of the highest b...                 No
# 4  Locate the purple structure and the block on i...                Yes
#
#   Partition   qrel                                              qbank  \
# 0     train    NaN                                                NaN
# 1     train    NaN                                                NaN
# 2     train    NaN                                                NaN
# 3     train  q_149  'q_696', 'q_203', 'q_516', 'q_677', 'q_769', '...
# 4     train    NaN                                                NaN
#
#                                            lowercase  \
# 0  destroy the two blocks over the row that is co...
# 1  place one yellow block on top of each purple b...
# 2  place one yellow block on top of each purple b...
# 3  place four blocks to the east of the highest b...
# 4  locate the purple structure and the block on i...
#
#                                         II_lowercase
# 0  destroy the two blocks over the row that is co...
# 1  place one yellow block on top of each purple b...
# 2  place one yellow block on top of each purple b...
# 3  place four blocks to the east of the highest b...
# 4  locate the purple structure and the block on i...

# %% [markdown]
# ### Remove the punctuation:

# %%
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(text):
    """custom function to remove the punctuation"""
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

C_questions["pnctRemoved"] = C_questions["lowercase"].apply(lambda text: remove_punctuation(text))
C_questions.head()
# Out:
#          GameId   ClarifyingQuestion  \
# 0     CQ-game-1                  NaN
# 1    CQ-game-10                  NaN
# 2    CQ-game-10                  NaN
# 3  CQ-game-1000  Which color blocks?
# 4  CQ-game-1001                  NaN
#
#                                 InitializedWorldPath  \
# 0  initial_world_states/builder-data/34-c135/step-20
# 1  initial_world_states/builder-data/12-c139/step-22
# 2  initial_world_states/builder-data/12-c139/step-22
# 3   initial_world_states/builder-data/23-c135/step-2
# 4    initial_world_states/builder-data/4-c96/step-18
#
#                                     InputInstruction IsInstructionClear  \
# 0  Destroy the two blocks over the row that is co...                Yes
# 1  Place one yellow block on top of each purple b...                Yes
# 2  Place one yellow block on top of each purple b...                Yes
# 3  Place four blocks to the east of the highest b...                 No
# 4  Locate the purple structure and the block on i...                Yes
#
#   Partition   qrel                                              qbank  \
# 0     train    NaN                                                NaN
# 1     train    NaN                                                NaN
# 2     train    NaN                                                NaN
# 3     train  q_149  'q_696', 'q_203', 'q_516', 'q_677', 'q_769', '...
# 4     train    NaN                                                NaN
#
#                                            lowercase  \
# 0  destroy the two blocks over the row that is co...
# 1  place one yellow block on top of each purple b...
# 2  place one yellow block on top of each purple b...
# 3  place four blocks to the east of the highest b...
# 4  locate the purple structure and the block on i...
#
#                                         II_lowercase  \
# 0  destroy the two blocks over the row that is co...
# 1  place one yellow block on top of each purple b...
# 2  place one yellow block on top of each purple b...
# 3  place four blocks to the east of the highest b...
# 4  locate the purple structure and the block on i...
#
#                                          pnctRemoved
# 0  destroy the two blocks over the row that is co...
# 1  place one yellow block on top of each purple b...
# 2  place one yellow block on top of each purple b...
# 3  place four blocks to the east of the highest b...
# 4  locate the purple structure and the block on i...

# %% [markdown]
# ### Remove the stopwords:

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """custom function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

C_questions["text_wo_stop"] = C_questions["pnctRemoved"].apply(lambda text: remove_stopwords(text))
C_questions.head()
# Out:
#          GameId   ClarifyingQuestion  \
# 0     CQ-game-1                  NaN
# 1    CQ-game-10                  NaN
# 2    CQ-game-10                  NaN
# 3  CQ-game-1000  Which color blocks?
# 4  CQ-game-1001                  NaN
#
#                                 InitializedWorldPath  \
# 0  initial_world_states/builder-data/34-c135/step-20
# 1  initial_world_states/builder-data/12-c139/step-22
# 2  initial_world_states/builder-data/12-c139/step-22
# 3   initial_world_states/builder-data/23-c135/step-2
# 4    initial_world_states/builder-data/4-c96/step-18
#
#                                     InputInstruction IsInstructionClear  \
# 0  Destroy the two blocks over the row that is co...                Yes
# 1  Place one yellow block on top of each purple b...                Yes
# 2  Place one yellow block on top of each purple b...                Yes
# 3  Place four blocks to the east of the highest b...                 No
# 4  Locate the purple structure and the block on i...                Yes
#
#   Partition   qrel                                              qbank  \
# 0     train    NaN                                                NaN
# 1     train    NaN                                                NaN
# 2     train    NaN                                                NaN
# 3     train  q_149  'q_696', 'q_203', 'q_516', 'q_677', 'q_769', '...
# 4     train    NaN                                                NaN
#
#                                            lowercase  \
# 0  destroy the two blocks over the row that is co...
# 1  place one yellow block on top of each purple b...
# 2  place one yellow block on top of each purple b...
# 3  place four blocks to the east of the highest b...
# 4  locate the purple structure and the block on i...
#
#                                         II_lowercase  \
# 0  destroy the two blocks over the row that is co...
# 1  place one yellow block on top of each purple b...
# 2  place one yellow block on top of each purple b...
# 3  place four blocks to the east of the highest b...
# 4  locate the purple structure and the block on i...
#
#                                          pnctRemoved  \
# 0  destroy the two blocks over the row that is co...
# 1  place one yellow block on top of each purple b...
# 2  place one yellow block on top of each purple b...
# 3  place four blocks to the east of the highest b...
# 4  locate the purple structure and the block on i...
#
#                                         text_wo_stop
# 0  destroy two blocks row connected column also d...
# 1    place one yellow block top purple block top row
# 2    place one yellow block top purple block top row
# 3  place four blocks east highest block horizontally
# 4  locate purple structure block eastern part pla...

# %% [markdown]
# ### Lemmatization:

# %%
#Lemmatization
C_questions["text_lemmatized"] = C_questions["text_wo_stop"].apply(lambda text: lemmatize_words(text))
C_questions.head()
# Out:
#          GameId   ClarifyingQuestion  \
# 0     CQ-game-1                  NaN
# 1    CQ-game-10                  NaN
# 2    CQ-game-10                  NaN
# 3  CQ-game-1000  Which color blocks?
# 4  CQ-game-1001                  NaN
#
#                                 InitializedWorldPath  \
# 0  initial_world_states/builder-data/34-c135/step-20
# 1  initial_world_states/builder-data/12-c139/step-22
# 2  initial_world_states/builder-data/12-c139/step-22
# 3   initial_world_states/builder-data/23-c135/step-2
# 4    initial_world_states/builder-data/4-c96/step-18
#
#                                     InputInstruction IsInstructionClear  \
# 0  Destroy the two blocks over the row that is co...                Yes
# 1  Place one yellow block on top of each purple b...                Yes
# 2  Place one yellow block on top of each purple b...                Yes
# 3  Place four blocks to the east of the highest b...                 No
# 4  Locate the purple structure and the block on i...                Yes
#
#   Partition   qrel                                              qbank  \
# 0     train    NaN                                                NaN
# 1     train    NaN                                                NaN
# 2     train    NaN                                                NaN
# 3     train  q_149  'q_696', 'q_203', 'q_516', 'q_677', 'q_769', '...
# 4     train    NaN                                                NaN
#
#                                            lowercase  \
# 0  destroy the two blocks over the row that is co...
# 1  place one yellow block on top of each purple b...
# 2  place one yellow block on top of each purple b...
# 3  place four blocks to the east of the highest b...
# 4  locate the purple structure and the block on i...
#
#                                         II_lowercase  \
# 0  destroy the two blocks over the row that is co...
# 1  place one yellow block on top of each purple b...
# 2  place one yellow block on top of each purple b...
# 3  place four blocks to the east of the highest b...
# 4  locate the purple structure and the block on i...
#
#                                          pnctRemoved  \
# 0  destroy the two blocks over the row that is co...
# 1  place one yellow block on top of each purple b...
# 2  place one yellow block on top of each purple b...
# 3  place four blocks to the east of the highest b...
# 4  locate the purple structure and the block on i...
#
#                                         text_wo_stop  \
# 0  destroy two blocks row connected column also d...
# 1    place one yellow block top purple block top row
# 2    place one yellow block top purple block top row
# 3  place four blocks east highest block horizontally
# 4  locate purple structure block eastern part pla...
#
#                                      text_lemmatized
# 0  destroy two block row connect column also dest...
# 1    place one yellow block top purple block top row
# 2    place one yellow block top purple block top row
# 3      place four block east high block horizontally
# 4  locate purple structure block eastern part pla...

# %% [markdown]
# ### Save and download the preprocessed data:

# %%
C_questions.to_csv(r'cleaned_clarifyingQuestionsTrain.csv', index=False)
